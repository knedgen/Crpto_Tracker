# %%
import pandas as pd
import requests
import bs4

#gets Coin Market Cap homepage and converts to beautiful soup object
result = requests.get("https://coinmarketcap.com/")
soup = bs4.BeautifulSoup(result.text,'lxml')

#gathers names of top 10 cryptos and puts into a list
names = []
for name in soup.select('.iJjGCS')[8:]:
    names.append(name.text)

#grabs tickers
symbols = []
for syms in soup.select('.gGIpIK')[:]:
    symbols.append(syms.text)


#gets ranks
ranks = []
for rank in soup.select('.etpvrL')[0::2]:
    ranks.append(rank.text)


#for getting prices    
prices = []
for price in soup.select('div.sc-131di3y-0.cLgOOr')[0:]:
    prices.append(price.text)
prices        


# collects the market cap values
caps = []
for cap in soup.select('span.sc-1ow4cwt-1.ieFnWP'):
    caps.append(cap.text)

data = {'Name':names,
       'Ticker': symbols,
       'Rank': ranks,
       'Price': prices,
       'Market Cap': caps}

df = pd.DataFrame(data, columns=['Rank','Name','Ticker','Price','Market Cap'])
    
df
# Out:
#   Rank          Name Ticker       Price        Market Cap
# 0    1       Bitcoin    BTC  $31,692.65  $594,555,491,025
# 1    2      Ethereum    ETH   $1,906.02  $222,518,469,326
# 2    3        Tether   USDT       $1.00   $62,027,088,827
# 3    4  Binance Coin    BNB     $305.62   $51,781,583,044
# 4    5       Cardano    ADA       $1.19   $38,088,637,657
# 5    6           XRP    XRP     $0.5864   $27,100,080,725
# 6    7      USD Coin   USDC       $1.00   $26,646,616,216
# 7    8      Dogecoin   DOGE     $0.1842   $24,029,326,735
# 8    9      Polkadot    DOT      $12.60   $12,304,740,789
# 9   10   Binance USD   BUSD       $1.00   $11,202,478,652
